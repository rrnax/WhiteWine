# %%
import pandas as pd

# %%
white_wines = pd.read_csv("white_wine.csv", sep=";", skipinitialspace=True, header=0)

# %%
white_wines
# Out:
#      fixedacidity volatileacidity citricacid residualsugar chlorides  \
# 0               7             ,27        ,36          20,7      ,045
# 1             6,3              ,3        ,34           1,6      ,049
# 2             8,1             ,28         ,4           6,9       ,05
# 3             8,1             ,28         ,4           6,9       ,05
# 4             6,2             ,32        ,16             7      ,045
# ...           ...             ...        ...           ...       ...
# 3929          4,9            ,235        ,27         11,75       ,03
# 3930          6,2             ,21        ,29           1,6      ,039
# 3931          6,6             ,32        ,36             8      ,047
# 3932          6,5             ,24        ,19           1,2      ,041
# 3933          5,5             ,29         ,3           1,1      ,022
#
#      freesulfurdioxide totalsulfurdioxide density    pH sulphates alcohol  \
# ...
